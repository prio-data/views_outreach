# %% [markdown]
# # Compare old and new pipeline forecasts for single run

# %%
import requests
import pandas as pd
import json
import os
from pathlib import Path
import numpy as np

#import matplotlib.pyplot as plt

# External
import geopandas as gpd
import sqlalchemy as sa

# VIEWS
from viewser.operations import fetch
from views_mapper2.mapper2 import *
from views_mapper2.BBoxWriter import *
from views_mapper2.dictionary_writer import *
from ingester3.config import source_db_path
from views_forecasts.extensions import *
from viewser import Queryset, Column
from views_mapper2.mapper2 import Mapper2

# %% [markdown]
# ## General settings

# %% [markdown]
# ### Set end of history

# %%
eoh = 549
EndOfHistory = 549

# %% [markdown]
# ### Set steps to map

# %%
steps = [1, 3, 6, 12, 24, 36] # set step to plot

# %% [markdown]
# ### Fetch mapping functions

# %%
def custom_add_colorbar(
    self,
    cmap,
    vmin,
    vmax,
    location="right",
    size="5%",
    pad=0.1,
    transparency=None,
    labelsize=10,
    tickparams=None,
):
    norm = plt.Normalize(vmin, vmax)
    if isinstance(cmap, str):
        cmap = plt.get_cmap(cmap)
    cmap = color.force_alpha_colormap(cmap=cmap, alpha=transparency)
    scalar_to_rgba = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
    divider = make_axes_locatable(self.ax)
    self.cax = divider.append_axes(location, size, pad)
    self.cax.tick_params(labelsize=labelsize)

    tickvalues = (
        list(tickparams.values()) if tickparams is not None else None
    )
    self.cbar = plt.colorbar(
        scalar_to_rgba, cax=self.cax, ticks=tickvalues
    )
    if tickparams is not None:
        self.cbar.set_ticklabels(list(tickparams.keys()))
    return self

# Monkey patch the method
Mapper2.add_colorbar = custom_add_colorbar

custom_scale = [0, 3, 10, 30, 100, 300]
custom_1p = log1p_dict(custom_scale)

# %% [markdown]
# ## Fetch geometries

# %%
import os
home = os.path.expanduser("~")
#dropbox = home+'/ViEWS Dropbox/VIEWS research collaboration/Dissemination/Working Papers/Prediction Competition Preprint Maps/'
desktop = home+'/Desktop/' # (Toggle on to save to desktop) Change to your directory
#forecasts.to_csv(desktop+'forecasts.csv', index=False)

# %%
# CM

# Get country geometries to overlay as borders
engine = sa.create_engine(source_db_path) 
gdf_cm_master = gpd.GeoDataFrame.from_postgis(
    "SELECT id as country_id, name, in_africa, in_me, geom FROM prod.country",
    engine,
    geom_col='geom'
)
gdf_cm_master = gdf_cm_master.to_crs(4326)
gdf_cm = gdf_cm_master.copy()
gdf_cm
# Out:
#      country_id                   name  in_africa  in_me  \
# 0           236               Tanzania          1      0
# 1            65                 Russia          0      0
# 2            39         United Kingdom          0      0
# 3           189                   USSR          0      0
# 4            85                  Italy          0      0
# ..          ...                    ...        ...    ...
# 215         133            Afghanistan          0      0
# 216         187         Czechoslovakia          0      0
# 217         227  Serbia and Montenegro          0      0
# 218         230                 Serbia          0      0
# 219         239           Saudi Arabia          0      1
#
#                                                   geom
# 0    MULTIPOLYGON (((34.13636 -9.57117, 34.07444 -9...
# 1    MULTIPOLYGON (((104.26255 77.68518, 104.33638 ...
# 2    MULTIPOLYGON (((-4.86416 54.62722, -4.92250 54...
# 3    MULTIPOLYGON (((104.26255 77.68518, 104.33638 ...
# 4    MULTIPOLYGON (((12.75357 43.97100, 12.76472 43...
# ..                                                 ...
# 215  MULTIPOLYGON (((61.27655 35.60725, 61.29638 35...
# 216  MULTIPOLYGON (((14.73972 50.82388, 14.77153 50...
# 217  MULTIPOLYGON (((18.45555 42.56583, 18.46389 42...
# 218  MULTIPOLYGON (((20.08568 42.54815, 20.10469 42...
# 219  MULTIPOLYGON (((51.21523 18.82156, 49.99998 18...
#
# [220 rows x 5 columns]

# %%
# PGM

# Get priogrid geometries
engine = sa.create_engine(source_db_path)
gdf_pgm_master = gpd.GeoDataFrame.from_postgis(
    "SELECT id as pg_id, in_africa, in_me, geom FROM prod.priogrid", 
    engine, 
    geom_col='geom'
)
gdf_pgm_master = gdf_pgm_master.to_crs(4326)
gdf_pgm = gdf_pgm_master.copy()

gdf_pgm.rename(columns = {'pg_id':'priogrid_id'}, inplace = True)
gdf_pgm
# Out:
#        priogrid_id  in_africa  in_me  \
# 0           240318      False  False
# 1           173423      False  False
# 2           234640      False  False
# 3           211904      False  False
# 4           218313      False  False
# ...            ...        ...    ...
# 64813       169611       True   True
# 64814       153089      False   True
# 64815       172514      False   True
# 64816       170344       True   True
# 64817       156697      False   True
#
#                                                     geom
# 0      POLYGON ((98.50000 76.50000, 98.50000 77.00000...
# 1      POLYGON ((131.00000 30.00000, 131.00000 30.500...
# 2      POLYGON ((139.50000 72.50000, 139.50000 73.000...
# 3      POLYGON ((-68.50000 57.00000, -68.50000 57.500...
# 4      POLYGON ((-104.00000 61.50000, -104.00000 62.0...
# ...                                                  ...
# 64813  POLYGON ((25.00000 27.50000, 25.00000 28.00000...
# 64814  POLYGON ((44.00000 16.00000, 44.00000 16.50000...
# 64815  POLYGON ((36.50000 29.50000, 36.50000 30.00000...
# 64816  POLYGON ((31.50000 28.00000, 31.50000 28.50000...
# 64817  POLYGON ((48.00000 18.50000, 48.00000 19.00000...
#
# [64818 rows x 4 columns]

# %% [markdown]
# ## Fetch old pipeline forecasts

# %% [markdown]
# ### Set old run_id and run names

# %%
old_run_id = 46
old_run_name_cm = f'cm_genetic_ensemble_f{eoh}'
old_run_name_pgm = f'pgm_ensemble_cm_calib_f{eoh}'

# %% [markdown]
# ### Get list of old cm runs - should only return one result

# %%
ViewsMetadata().with_name(name=old_run_name_cm).fetch()
# Out:
#       id                      name                               file_name  \
# 0  23316  cm_genetic_ensemble_f549  pr_46_cm_genetic_ensemble_f549.parquet
#
#    runs_id  model_generations_id user_name spatial_loa temporal_loa     ds  \
# 0       46                     1  angelica           c            m  False
#
#      osa  time_min  time_max  space_min  space_max steps         target  \
# 0  False       550       585          1        246    []  step_combined
#
#   prediction_columns                     date_written description  deleted
# 0                 [] 2025-10-27 11:24:59.630812+00:00        None    False

# %% [markdown]
# ### Get list of old pgm runs - should only return one result

# %%
ViewsMetadata().with_name(name=old_run_name_pgm).fetch()
# Out:
#       id                        name  \
# 0  23360  pgm_ensemble_cm_calib_f549
#
#                                   file_name  runs_id  model_generations_id  \
# 0  pr_46_pgm_ensemble_cm_calib_f549.parquet       46                     1
#
#   user_name spatial_loa temporal_loa     ds    osa  time_min  time_max  \
# 0  angelica          pg            m  False  False       550       585
#
#    space_min  space_max steps         target prediction_columns  \
# 0      62356     190511    []  step_combined                 []
#
#                       date_written description  deleted
# 0 2025-10-27 15:59:48.620817+00:00        None    False

# %% [markdown]
# ### Fetch dfs for old data

# %%
old_data_cm = pd.DataFrame.forecasts.read_store(run=old_run_id, name=old_run_name_cm)
old_data_pgm = pd.DataFrame.forecasts.read_store(run=old_run_id, name=old_run_name_pgm)
# Out:
# pr_46_cm_genetic_ensemble_f549.parquet
# pr_46_pgm_ensemble_cm_calib_f549.parquet

# %% [markdown]
# ### Quick check that the df's look ok

# %%
old_data_cm
# Out:
# feature              step_combined
# month_id country_id
# 550      1                0.001749
#          2                0.003540
#          3                0.043151
#          4                0.742192
#          5                0.009478
# ...                            ...
# 585      242              0.343062
#          243              0.629551
#          244              0.317161
#          245              5.258471
#          246              3.352334
#
# [6876 rows x 1 columns]

# %%
old_data_pgm
# Out:
# feature               step_combined
# month_id priogrid_id
# 550      62356             0.000184
#          79599             0.000081
#          79600             0.000078
#          79601             0.000074
#          80317             0.000103
# ...                             ...
# 585      190496            0.009952
#          190507            0.001289
#          190508            0.001099
#          190510            0.001199
#          190511            0.001106
#
# [471960 rows x 1 columns]

# %% [markdown]
# ## Fetch new pipeline forecasts

# %% [markdown]
# ### Set new run id and run names

# %%
new_run_id = 67
new_runs_cm = f'pink_ponyclub_predictions_forecasting'
new_runs_pgm = f'skinny_love_predictions_forecasting_'

# %% [markdown]
# ### Select new cm run

# %%
# Get list of new cm runs - may return many results
ViewsMetadata().with_name(name=new_runs_cm).fetch()
# Out:
#       id                                               name  \
# 0  23157  pink_ponyclub_predictions_forecasting_20251009...
# 1  23192  pink_ponyclub_predictions_forecasting_20251016...
# 2  23256  pink_ponyclub_predictions_forecasting_20251024...
# 3  23333  pink_ponyclub_predictions_forecasting_20251027...
#
#                                            file_name  runs_id  \
# 0  pr_67_pink_ponyclub_predictions_forecasting_20...       67
# 1  pr_67_pink_ponyclub_predictions_forecasting_20...       67
# 2  pr_67_pink_ponyclub_predictions_forecasting_20...       67
# 3  pr_67_pink_ponyclub_predictions_forecasting_20...       67
#
#    model_generations_id   user_name spatial_loa temporal_loa     ds    osa  \
# 0                     1  ‘xiaolong’           c            m  False  False
# 1                     1         jim           c            m  False  False
# 2                     1  ‘xiaolong’           c            m  False  False
# 3                     1  ‘xiaolong’           c            m  False  False
#
#    time_min  time_max  space_min  space_max steps              target  \
# 0       550       585          1        246    []  pred_ln_ged_sb_dep
# 1       549       584          1        246    []  pred_ln_ged_sb_dep
# 2       550       585          1        246    []  pred_ln_ged_sb_dep
# 3       550       585          1        246    []  pred_ln_ged_sb_dep
#
#   prediction_columns                     date_written description  deleted
# 0                 [] 2025-10-09 11:06:04.322679+00:00        None    False
# 1                 [] 2025-10-16 13:32:41.156497+00:00        None    False
# 2                 [] 2025-10-24 14:54:22.122957+00:00        None    False
# 3                 [] 2025-10-27 11:39:07.875302+00:00        None    False

# %%
# Select the last run in the df - this is the most recent, and presumably therefore the one we want
new_data_cm_name = ViewsMetadata().with_name(name=new_runs_cm).fetch().iloc[-2]['name']
new_data_cm_name
# Out:
# 'pink_ponyclub_predictions_forecasting_20251024_145418'

# %% [markdown]
# ### Select new pgm run

# %%
# Get list of new pgm runs - may return many results
ViewsMetadata().with_name(name=new_runs_pgm).fetch()
# Out:
#       id                                               name  \
# 0  23170  skinny_love_predictions_forecasting_20251011_1...
# 1  23172  skinny_love_predictions_forecasting_20251014_1...
# 2  23269  skinny_love_predictions_forecasting_20251024_2...
#
#                                            file_name  runs_id  \
# 0  pr_67_skinny_love_predictions_forecasting_2025...       67
# 1  pr_67_skinny_love_predictions_forecasting_2025...       67
# 2  pr_67_skinny_love_predictions_forecasting_2025...       67
#
#    model_generations_id   user_name spatial_loa temporal_loa     ds    osa  \
# 0                     1  ‘xiaolong’          pg            m  False  False
# 1                     1  ‘xiaolong’          pg            m  False  False
# 2                     1  ‘xiaolong’          pg            m  False  False
#
#    time_min  time_max  space_min  space_max steps              target  \
# 0       550       585      62356     190511    []  pred_ln_ged_sb_dep
# 1       550       585      62356     190511    []  pred_ln_ged_sb_dep
# 2       550       585      62356     190511    []  pred_ln_ged_sb_dep
#
#   prediction_columns                     date_written description  deleted
# 0                 [] 2025-10-11 16:48:45.115231+00:00        None    False
# 1                 [] 2025-10-14 15:24:46.573238+00:00        None    False
# 2                 [] 2025-10-24 20:21:18.729988+00:00        None    False

# %%
# Select the last run in the df - this is the most recent, and presumably therefore the one we want
new_data_pgm_name = ViewsMetadata().with_name(name=new_runs_pgm).fetch().iloc[-1]['name']
new_data_pgm_name
# Out:
# 'skinny_love_predictions_forecasting_20251024_202114'

# %% [markdown]
# ### Fetch data for new runs

# %%
new_data_cm = pd.DataFrame.forecasts.read_store(run=new_run_id, name=new_data_cm_name)
new_data_pgm = pd.DataFrame.forecasts.read_store(run=new_run_id, name=new_data_pgm_name)
# Out:
# pr_67_pink_ponyclub_predictions_forecasting_20251024_145418.parquet
# pr_67_skinny_love_predictions_forecasting_20251024_202114.parquet

# %% [markdown]
# ## Prep and plot new pipeline CM forecasts

# %%
new_data_cm
# Out:
#                      pred_ln_ged_sb_dep
# month_id country_id
# 550      1                     0.003773
#          2                     0.003762
#          3                     0.011403
#          4                     0.713244
#          5                     0.003762
# ...                                 ...
# 585      242                   0.105974
#          243                   0.378329
#          244                   0.107760
#          245                   3.757777
#          246                   2.260278
#
# [6876 rows x 1 columns]

# %%
# Add steps and streamline index
new_data_cm = new_data_cm.reset_index()
new_data_cm['step'] = new_data_cm['month_id'] - EndOfHistory
new_data_cm = new_data_cm.set_index(['step', 'country_id'], drop = True)
new_data_cm
# Out:
#                  month_id  pred_ln_ged_sb_dep
# step country_id
# 1    1                550            0.003773
#      2                550            0.003762
#      3                550            0.011403
#      4                550            0.713244
#      5                550            0.003762
# ...                   ...                 ...
# 36   242              585            0.105974
#      243              585            0.378329
#      244              585            0.107760
#      245              585            3.757777
#      246              585            2.260278
#
# [6876 rows x 2 columns]

# %%
## Merge in geometries
cm_data_new = pd.merge(new_data_cm, gdf_cm, on="country_id", how="left")
gdf_cm_new = gpd.GeoDataFrame(cm_data_new, geometry="geom")

gdf_cm_new
# Out:
#       country_id  month_id  pred_ln_ged_sb_dep                 name  \
# 0              1       550            0.003773               Guyana
# 1              2       550            0.003762             Suriname
# 2              3       550            0.011403  Trinidad and Tobago
# 3              4       550            0.713244            Venezuela
# 4              5       550            0.003762                Samoa
# ...          ...       ...                 ...                  ...
# 6871         242       585            0.105974             Tanzania
# 6872         243       585            0.378329              Morocco
# 6873         244       585            0.107760           Mauritania
# 6874         245       585            3.757777                Sudan
# 6875         246       585            2.260278          South Sudan
#
#       in_africa  in_me                                               geom
# 0             0      0  MULTIPOLYGON (((-58.17262 6.81222, -58.15494 6...
# 1             0      0  MULTIPOLYGON (((-55.12796 5.82217, -55.10445 5...
# 2             0      0  MULTIPOLYGON (((-61.07945 10.82416, -61.07556 ...
# 3             0      0  MULTIPOLYGON (((-66.31029 10.62602, -66.28309 ...
# 4             0      0  MULTIPOLYGON (((-172.59650 -13.50911, -172.551...
# ...         ...    ...                                                ...
# 6871          1      0  MULTIPOLYGON (((34.13636 -9.57117, 34.07444 -9...
# 6872          1      0  MULTIPOLYGON (((-4.42042 35.15125, -4.35792 35...
# 6873          1      0  MULTIPOLYGON (((-10.71639 15.43890, -10.71945 ...
# 6874          1      0  MULTIPOLYGON (((34.09223 9.47747, 33.90162 9.4...
# 6875          1      0  MULTIPOLYGON (((34.09223 9.47747, 34.09416 9.4...
#
# [6876 rows x 7 columns]

# %%
# Plot the new pipeline CM forecasts

for step in steps:

    # Generate month to plot based on first month of selected dataset and the step chosen above

    t = (new_data_cm['month_id'].min())-1
    month_to_plot = t + step 
    month_to_plot

    cm_data_to_plot = gdf_cm_new[gdf_cm_new['month_id'] == month_to_plot]  
    region = 'globe' #options are 'ame', 'me' or 'globe'

    cmap = ['rainbow']

    for cmaps in cmap:
        test_map = Mapper2(
        width=10,   # dimension width
        height=10,  # dimension height
        frame_on=True,
        bbox=bbox_from_cid(f'{region}'), 
        ).add_layer(
        gdf=cm_data_to_plot,  
        cmap=cmaps,
        transparency=1,
        background=None, 
        map_dictionary=dictionary_stand_1p_10k, # changed based on column
        edgecolor="black",  # border color choice
        linewidth=0.15,  # line size choice
        column="pred_ln_ged_sb_dep", 
        )

    # Save the map with appropriate filename
    test_map.save(f'{desktop}/new_run_{EndOfHistory}_cm_s{step}_ln1_{region}_{cmaps}', dpi=350)

    # Print map status
    print(f'{cmaps} map for step {step} saved to {desktop}/new_run_{EndOfHistory}_cm_s{step}_ln1_{region}_{cmaps}!')
# Out:
# rainbow map for step 1 saved to /Users/alm/Desktop//new_run_549_cm_s1_ln1_globe_rainbow!
# rainbow map for step 3 saved to /Users/alm/Desktop//new_run_549_cm_s3_ln1_globe_rainbow!
# rainbow map for step 6 saved to /Users/alm/Desktop//new_run_549_cm_s6_ln1_globe_rainbow!
# rainbow map for step 12 saved to /Users/alm/Desktop//new_run_549_cm_s12_ln1_globe_rainbow!
# rainbow map for step 24 saved to /Users/alm/Desktop//new_run_549_cm_s24_ln1_globe_rainbow!
# rainbow map for step 36 saved to /Users/alm/Desktop//new_run_549_cm_s36_ln1_globe_rainbow!

# %% [markdown]
# ## Prep and plot new pipeline PGM forecasts

# %%
# The pgm data currently has a single-element vector as every value in the forecast column - we need to crudely fix this
pgm_values = new_data_pgm['pred_ln_ged_sb_dep'].values

# %%
pgm_values
# Out:
# array([array([5.3644035e-06], dtype=float32),
#        array([2.503392e-06], dtype=float32),
#        array([4.2915253e-06], dtype=float32), ...,
#        array([8.427742e-05], dtype=float32),
#        array([8.427742e-05], dtype=float32),
#        array([8.427742e-05], dtype=float32)], dtype=object)

# %%
pgm_values_scalar = [pgm_val[0] for pgm_val in pgm_values]

# %%
pgm_values_scalar
# Out:
# [5.3644035e-06,
#  2.503392e-06,
#  4.2915253e-06,
#  3.4570635e-06,
#  6.4372807e-06,
#  1.5735503e-05,
#  1.2278481e-05,
#  5.1259863e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  5.245195e-06,
#  2.7418098e-06,
#  5.7220295e-06,
#  2.503392e-06,
#  5.3644035e-06,
#  3.933899e-06,
#  4.1723165e-06,
#  7.3909487e-06,
#  4.1723165e-06,
#  4.1723165e-06,
#  0.00015889335,
#  0.00012647305,
#  9.417489e-06,
#  5.1259863e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  9.417489e-06,
#  5.1259863e-06,
#  2.7418098e-06,
#  5.9604467e-06,
#  4.1723165e-06,
#  4.1723165e-06,
#  1.20400655e-05,
#  2.0146166e-05,
#  5.841238e-06,
#  7.3909487e-06,
#  3.933899e-06,
#  2.503392e-06,
#  3.3378547e-06,
#  5.1259863e-06,
#  5.7220295e-06,
#  5.1259863e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.503392e-06,
#  2.503392e-06,
#  3.3378547e-06,
#  4.1723165e-06,
#  4.1723165e-06,
#  4.1723165e-06,
#  3.933899e-06,
#  3.933899e-06,
#  4.1723165e-06,
#  1.03711545e-05,
#  6.4372807e-06,
#  7.152532e-06,
#  5.1259863e-06,
#  5.841238e-06,
#  5.1259863e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  4.1723165e-06,
#  4.1723165e-06,
#  4.1723165e-06,
#  4.1723165e-06,
#  4.1723165e-06,
#  4.1723165e-06,
#  1.0132739e-05,
#  1.0847986e-05,
#  1.2159274e-05,
#  1.1563234e-05,
#  4.1723165e-06,
#  3.3378547e-06,
#  2.503392e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  5.245195e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  7.152532e-06,
#  9.655906e-06,
#  4.1723165e-06,
#  9.655906e-06,
#  4.1723165e-06,
#  6.675698e-06,
#  6.4372807e-06,
#  1.03711545e-05,
#  1.2159274e-05,
#  1.180165e-05,
#  4.1723165e-06,
#  6.9141147e-06,
#  5.245195e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  4.1723165e-06,
#  4.1723165e-06,
#  4.1723165e-06,
#  4.1723165e-06,
#  1.1086402e-05,
#  6.675698e-06,
#  1.1086402e-05,
#  1.0847986e-05,
#  1.2159274e-05,
#  1.28745205e-05,
#  4.1723165e-06,
#  3.4570635e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  3.0994368e-06,
#  4.1723165e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  3.0994368e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  3.0994368e-06,
#  3.0994368e-06,
#  3.0994368e-06,
#  3.3378547e-06,
#  4.1723165e-06,
#  4.1723165e-06,
#  4.1723165e-06,
#  7.152532e-06,
#  6.675698e-06,
#  9.536698e-06,
#  1.0847986e-05,
#  1.1086402e-05,
#  1.2159274e-05,
#  6.675698e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  3.0994368e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  3.0994368e-06,
#  3.0994368e-06,
#  5.7220295e-06,
#  2.7418098e-06,
#  4.1723165e-06,
#  4.1723165e-06,
#  4.1723165e-06,
#  8.940657e-06,
#  9.655906e-06,
#  8.106199e-06,
#  7.2717403e-06,
#  1.0490363e-05,
#  1.1086402e-05,
#  1.1086402e-05,
#  1.1444026e-05,
#  5.7220295e-06,
#  4.410734e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  3.0994368e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  5.0067774e-06,
#  9.655906e-06,
#  0.00031323294,
#  0.00031335212,
#  1.1086402e-05,
#  5.9604467e-06,
#  1.1086402e-05,
#  9.655906e-06,
#  1.1920858e-05,
#  2.7418098e-06,
#  3.0994368e-06,
#  5.7220295e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  5.0067774e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.503392e-06,
#  2.503392e-06,
#  0.0002944036,
#  0.00029511866,
#  0.00021705656,
#  0.000283082,
#  1.001353e-05,
#  9.7751135e-06,
#  1.5497088e-05,
#  2.5987287e-05,
#  3.4808505e-05,
#  3.4570635e-06,
#  2.7418098e-06,
#  3.0994368e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  5.0067774e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  4.1723165e-06,
#  5.7220295e-06,
#  3.0994368e-06,
#  2.7418098e-06,
#  3.0994368e-06,
#  2.7418098e-06,
#  4.1723165e-06,
#  2.7418098e-06,
#  5.6028207e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  1.0728779e-05,
#  8.70224e-06,
#  8.940657e-06,
#  0.000656985,
#  0.00021741411,
#  0.00029964725,
#  0.0002780766,
#  1.0251946e-05,
#  5.7220295e-06,
#  1.0132739e-05,
#  6.5564896e-06,
#  5.7220295e-06,
#  1.0251946e-05,
#  2.7418098e-06,
#  2.7418098e-06,
#  1.8119648e-05,
#  1.0251946e-05,
#  1.442422e-05,
#  1.6569955e-05,
#  2.7418098e-06,
#  5.3644035e-06,
#  8.225407e-06,
#  3.0994368e-06,
#  1.0490363e-05,
#  2.7418098e-06,
#  2.7418098e-06,
#  3.0994368e-06,
#  3.0994368e-06,
#  2.503392e-06,
#  9.417489e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.503392e-06,
#  2.503392e-06,
#  7.3909487e-06,
#  9.417489e-06,
#  0.000295357,
#  0.00031561637,
#  6.4372807e-06,
#  1.001353e-05,
#  9.536698e-06,
#  9.7751135e-06,
#  1.0132739e-05,
#  1.2755313e-05,
#  7.152532e-06,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.2993728e-05,
#  4.410734e-06,
#  1.0251946e-05,
#  1.0251946e-05,
#  2.1695856e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  2.7418098e-06,
#  2.7418098e-06,
#  8.940657e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  5.3644035e-06,
#  4.1723165e-06,
#  5.6028207e-06,
#  8.344616e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  5.1259863e-06,
#  8.940657e-06,
#  7.3909487e-06,
#  8.106199e-06,
#  9.417489e-06,
#  8.344616e-06,
#  8.821448e-06,
#  9.417489e-06,
#  1.0251946e-05,
#  9.536698e-06,
#  9.655906e-06,
#  6.4372807e-06,
#  6.4372807e-06,
#  3.2186456e-06,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  4.1723165e-06,
#  5.6028207e-06,
#  5.7220295e-06,
#  5.7220295e-06,
#  9.655906e-06,
#  7.510157e-06,
#  5.245195e-06,
#  7.3909487e-06,
#  9.417489e-06,
#  9.417489e-06,
#  5.1259863e-06,
#  7.3909487e-06,
#  5.1259863e-06,
#  2.7418098e-06,
#  8.940657e-06,
#  1.0847986e-05,
#  1.0132739e-05,
#  5.9604467e-06,
#  1.0251946e-05,
#  9.536698e-06,
#  3.3378547e-06,
#  1.6569955e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  0.0017729768,
#  8.106199e-06,
#  7.3909487e-06,
#  5.3644035e-06,
#  7.510157e-06,
#  8.225407e-06,
#  8.225407e-06,
#  6.5564896e-06,
#  8.70224e-06,
#  2.503392e-06,
#  8.106199e-06,
#  2.503392e-06,
#  5.1259863e-06,
#  5.245195e-06,
#  8.225407e-06,
#  2.6583319e-05,
#  9.655906e-06,
#  8.880698e-05,
#  0.008594075,
#  6.5564896e-06,
#  7.6293654e-06,
#  2.1695856e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  2.1695856e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.8954097e-05,
#  2.7418098e-06,
#  1.6093125e-05,
#  1.6569955e-05,
#  1.9311718e-05,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  5.245195e-06,
#  7.867782e-06,
#  8.225407e-06,
#  5.3644035e-06,
#  7.510157e-06,
#  8.106199e-06,
#  9.536698e-06,
#  9.417489e-06,
#  1.3708975e-05,
#  5.7220295e-06,
#  5.1259863e-06,
#  9.417489e-06,
#  8.344616e-06,
#  5.1259863e-06,
#  1.0847986e-05,
#  0.020909356,
#  0.005412448,
#  0.000487328,
#  0.000487328,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.585471e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  2.7418098e-06,
#  4.887569e-06,
#  1.41858045e-05,
#  1.41858045e-05,
#  2.7179349e-05,
#  2.7418098e-06,
#  2.7418098e-06,
#  2.7418098e-06,
#  5.0067774e-06,
#  2.7418098e-06,
#  8.225407e-06,
#  9.059865e-06,
#  8.821448e-06,
#  7.748574e-06,
#  9.417489e-06,
#  2.5510462e-05,
#  6.377493e-05,
#  8.70224e-06,
#  9.417489e-06,
#  5.3644035e-06,
#  8.106199e-06,
#  3.778863e-05,
#  0.021039866,
#  0.0030096732,
#  0.0051291543,
#  0.0011604249,
#  1.2993728e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  2.1695856e-05,
#  1.0251946e-05,
#  2.7418098e-06,
#  1.9311718e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.9311718e-05,
#  2.7418098e-06,
#  2.7418098e-06,
#  4.887569e-06,
#  3.6834994e-05,
#  1.2636105e-05,
#  9.536698e-06,
#  5.7220295e-06,
#  5.245195e-06,
#  1.0728779e-05,
#  1.060957e-05,
#  2.7536968e-05,
#  8.940657e-06,
#  5.2212305e-05,
#  5.1259863e-06,
#  5.1259863e-06,
#  8.106199e-06,
#  8.487341e-05,
#  6.603976e-05,
#  0.011574615,
#  0.040576566,
#  2.6583319e-05,
#  2.6583319e-05,
#  1.2993728e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  2.7418098e-06,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.537788e-05,
#  2.9325056e-05,
#  1.41858045e-05,
#  2.6583319e-05,
#  2.6106494e-05,
#  2.5629668e-05,
#  3.6954196e-05,
#  8.225407e-06,
#  8.940657e-06,
#  9.417489e-06,
#  9.417489e-06,
#  1.490105e-05,
#  9.536698e-06,
#  9.417489e-06,
#  8.70224e-06,
#  8.106199e-06,
#  1.001353e-05,
#  8.821448e-06,
#  0.00014733183,
#  0.0009963316,
#  0.0010399178,
#  0.0010992206,
#  0.0010236029,
#  0.00028868322,
#  3.111314e-05,
#  4.672895e-05,
#  4.458328e-05,
#  6.2940526e-05,
#  5.078187e-05,
#  4.672895e-05,
#  2.6583319e-05,
#  1.6569955e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.8954097e-05,
#  1.0251946e-05,
#  2.2411095e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.3708975e-05,
#  1.3708975e-05,
#  2.5629668e-05,
#  8.0105434e-05,
#  9.655906e-06,
#  5.7220295e-06,
#  8.106199e-06,
#  5.7220295e-06,
#  8.940657e-06,
#  8.225407e-06,
#  9.417489e-06,
#  9.536698e-06,
#  9.417489e-06,
#  8.106199e-06,
#  1.0728779e-05,
#  2.503392e-06,
#  0.00027831495,
#  0.00069594005,
#  0.0007127367,
#  0.0007344171,
#  0.0056665028,
#  0.0008334024,
#  0.00028868322,
#  2.6583319e-05,
#  4.2199197e-05,
#  5.9006856e-05,
#  6.0556486e-05,
#  5.161629e-05,
#  4.6252135e-05,
#  6.5086155e-05,
#  4.672895e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  2.4795225e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  2.4318399e-05,
#  1.3708975e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  2.6106494e-05,
#  3.8146245e-05,
#  3.1470758e-05,
#  1.0847986e-05,
#  2.503392e-06,
#  2.503392e-06,
#  5.245195e-06,
#  8.940657e-06,
#  9.417489e-06,
#  9.417489e-06,
#  9.417489e-06,
#  8.106199e-06,
#  2.503392e-06,
#  3.2186456e-06,
#  0.00027831495,
#  0.0006625841,
#  0.005517255,
#  0.00045861216,
#  0.00045861216,
#  0.0004782725,
#  0.005560763,
#  4.672895e-05,
#  4.2199197e-05,
#  4.2199197e-05,
#  5.161629e-05,
#  4.458328e-05,
#  4.458328e-05,
#  4.2199197e-05,
#  4.672895e-05,
#  2.8729026e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.1682442e-05,
#  1.0251946e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  2.4199193e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  3.492771e-05,
#  3.492771e-05,
#  3.194758e-05,
#  2.3722367e-05,
#  4.1723165e-06,
#  5.245195e-06,
#  5.9604467e-06,
#  9.059865e-06,
#  1.0728779e-05,
#  8.940657e-06,
#  1.060957e-05,
#  8.70224e-06,
#  9.655906e-06,
#  0.097645275,
#  0.00028868322,
#  0.00028868322,
#  0.00028868322,
#  0.00028868322,
#  0.00028868322,
#  0.0005598885,
#  0.0045172316,
#  0.00045861216,
#  4.2199197e-05,
#  5.161629e-05,
#  5.5549986e-05,
#  4.2199197e-05,
#  4.2199197e-05,
#  4.2199197e-05,
#  4.2199197e-05,
#  4.2199197e-05,
#  4.2199197e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  2.2411095e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.9192512e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.537788e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.537788e-05,
#  3.445089e-05,
#  1.3708975e-05,
#  2.9801879e-05,
#  2.4318399e-05,
#  6.675698e-06,
#  5.245195e-06,
#  8.225407e-06,
#  9.417489e-06,
#  9.417489e-06,
#  9.536698e-06,
#  1.0728779e-05,
#  2.7418098e-06,
#  0.00028868322,
#  0.00028868322,
#  0.00028868322,
#  0.00028868322,
#  0.00028868322,
#  0.00028868322,
#  0.00045861216,
#  0.0056665028,
#  0.00028868322,
#  2.6583319e-05,
#  5.233151e-05,
#  4.458328e-05,
#  4.2199197e-05,
#  4.2199197e-05,
#  4.2199197e-05,
#  5.6503606e-05,
#  4.2199197e-05,
#  4.6252135e-05,
#  6.603976e-05,
#  1.0251946e-05,
#  3.3616456e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.9788546e-05,
#  8.1774226e-05,
#  9.655906e-06,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.537788e-05,
#  1.537788e-05,
#  1.41858045e-05,
#  1.8596476e-05,
#  1.3708975e-05,
#  1.3708975e-05,
#  2.3722367e-05,
#  2.5629668e-05,
#  2.5629668e-05,
#  6.4372807e-06,
#  6.675698e-06,
#  5.7220295e-06,
#  8.225407e-06,
#  9.536698e-06,
#  9.417489e-06,
#  4.1723165e-06,
#  0.00028868322,
#  0.00028868322,
#  0.00028868322,
#  0.00028868322,
#  0.00028868322,
#  0.00028868322,
#  0.00045861216,
#  0.0005598885,
#  0.00028868322,
#  4.672895e-05,
#  6.5086155e-05,
#  4.2199197e-05,
#  2.6583319e-05,
#  2.6583319e-05,
#  4.2199197e-05,
#  4.2199197e-05,
#  4.2199197e-05,
#  5.5549986e-05,
#  0.0001859492,
#  1.2993728e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.9192512e-05,
#  9.655906e-06,
#  1.0251946e-05,
#  2.2411095e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  2.1815062e-05,
#  2.3126335e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.3708975e-05,
#  1.3708975e-05,
#  1.3708975e-05,
#  1.3708975e-05,
#  2.5987287e-05,
#  2.2053475e-05,
#  2.3126335e-05,
#  1.3112935e-05,
#  2.2053475e-05,
#  3.4570635e-06,
#  4.887569e-06,
#  2.8729026e-05,
#  3.5881352e-05,
#  3.194758e-05,
#  0.00049280893,
#  0.00028868322,
#  0.00028868322,
#  0.00028868322,
#  0.00043609168,
#  0.0004440752,
#  0.0006625841,
#  0.0005274812,
#  0.00028868322,
#  3.70734e-05,
#  5.9006856e-05,
#  4.2199197e-05,
#  4.458328e-05,
#  2.6583319e-05,
#  2.6583319e-05,
#  4.2199197e-05,
#  4.2199197e-05,
#  4.6252135e-05,
#  6.305973e-05,
#  4.2199197e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  2.1695856e-05,
#  1.0251946e-05,
#  2.1695856e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.585471e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.537788e-05,
#  2.4795225e-05,
#  1.537788e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.9192512e-05,
#  1.3708975e-05,
#  1.3708975e-05,
#  1.3708975e-05,
#  1.3708975e-05,
#  1.3708975e-05,
#  1.3112935e-05,
#  2.9325056e-05,
#  2.193427e-05,
#  2.4437606e-05,
#  4.148397e-05,
#  3.5762147e-05,
#  4.3033626e-05,
#  2.8490615e-05,
#  2.8490615e-05,
#  2.9325056e-05,
#  0.00028868322,
#  0.00028868322,
#  0.00028868322,
#  0.00028868322,
#  0.00031454384,
#  0.00045861216,
#  0.00563106,
#  3.111314e-05,
#  4.458328e-05,
#  2.6583319e-05,
#  2.6583319e-05,
#  2.6583319e-05,
#  2.6583319e-05,
#  4.2199197e-05,
#  4.6252135e-05,
#  7.092701e-05,
#  6.0556486e-05,
#  5.2689116e-05,
#  1.7523613e-05,
#  1.2993728e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  2.1695856e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.585471e-05,
#  1.1682442e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.0251946e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  2.4199193e-05,
#  1.41858045e-05,
#  1.41858045e-05,
#  1.537788e-05,
#  1.490105e-05,
#  1.3708975e-05,
#  2.4318399e-05,
#  1.3708975e-05,
#  1.3708975e-05,
#  2.1338235e-05,
#  2.3841574e-05,
#  3.5404533e-05,
#  2.8490615e-05,
#  3.5762147e-05,
#  4.3033626e-05,
#  4.3033626e-05,
#  2.8490615e-05,
#  6.580136e-05,
#  4.398726e-05,
#  4.398726e-05,
#  3.2066786e-05,
#  0.00045861216,
#  0.0006404256,
#  0.00028868322,
#  0.00028868322,
#  0.0005598885,
#  0.00028868322,
#  2.6583319e-05,
#  3.70734e-05,
#  4.2199197e-05,
#  3.5881352e-05,
#  2.6583319e-05,
#  2.6583319e-05,
#  4.2199197e-05,
#  4.6252135e-05,
#  0.00010895135,
#  4.6252135e-05,
#  ...]

# %%
new_data_pgm['pred_ln_ged_sb_dep'] = pgm_values_scalar
new_data_pgm
# Out:
#                       pred_ln_ged_sb_dep
# month_id priogrid_id
# 550      62356                  0.000005
#          79599                  0.000003
#          79600                  0.000004
#          79601                  0.000003
#          80317                  0.000006
# ...                                  ...
# 585      190496                 0.104910
#          190507                 0.000084
#          190508                 0.000084
#          190510                 0.000084
#          190511                 0.000084
#
# [471960 rows x 1 columns]

# %%
# reset index
new_data_pgm = new_data_pgm.reset_index()
new_data_pgm
# Out:
#         month_id  priogrid_id  pred_ln_ged_sb_dep
# 0            550        62356            0.000005
# 1            550        79599            0.000003
# 2            550        79600            0.000004
# 3            550        79601            0.000003
# 4            550        80317            0.000006
# ...          ...          ...                 ...
# 471955       585       190496            0.104910
# 471956       585       190507            0.000084
# 471957       585       190508            0.000084
# 471958       585       190510            0.000084
# 471959       585       190511            0.000084
#
# [471960 rows x 3 columns]

# %%
# fetch pg identifiers
qs_pg = (Queryset("c_pg", "priogrid_month")

               # target variable
               .with_column(Column("gwcode", from_loa="country", from_column="gwcode")
                            )
               .with_column(Column("name", from_loa="country", from_column="name")
                            )
        )
pg_identifiers=qs_pg.publish().fetch()
pg_identifiers
# Out:
# 100%|██████████| 20.9M/20.9M [00:01<00:00, 12.5MB/s]
# Queryset c_pg read successfully
#                        gwcode          name
# month_id priogrid_gid
# 1        62356            560  South Africa
#          79599            560  South Africa
#          79600            560  South Africa
#          79601            560  South Africa
#          80317            560  South Africa
# ...                       ...           ...
# 852      190496           355      Bulgaria
#          190507           640        Turkey
#          190508           640        Turkey
#          190510           640        Turkey
#          190511           640        Turkey
#
# [11169720 rows x 2 columns]

# %%
# reset index and fix inconsistent col names
pg_identifiers = pg_identifiers.reset_index()
pg_identifiers = pg_identifiers.rename(columns = {'priogrid_gid':'priogrid_id'})
pg_identifiers
# Out:
#           month_id  priogrid_id  gwcode          name
# 0                1        62356     560  South Africa
# 1                1        79599     560  South Africa
# 2                1        79600     560  South Africa
# 3                1        79601     560  South Africa
# 4                1        80317     560  South Africa
# ...            ...          ...     ...           ...
# 11169715       852       190496     355      Bulgaria
# 11169716       852       190507     640        Turkey
# 11169717       852       190508     640        Turkey
# 11169718       852       190510     640        Turkey
# 11169719       852       190511     640        Turkey
#
# [11169720 rows x 4 columns]

# %%
# merge with forecasts
pgm_data_new = pd.merge(new_data_pgm, pg_identifiers, on=["priogrid_id", "month_id"], how="left")
pgm_data_new
# Out:
#         month_id  priogrid_id  pred_ln_ged_sb_dep  gwcode          name
# 0            550        62356            0.000005     560  South Africa
# 1            550        79599            0.000003     560  South Africa
# 2            550        79600            0.000004     560  South Africa
# 3            550        79601            0.000003     560  South Africa
# 4            550        80317            0.000006     560  South Africa
# ...          ...          ...                 ...     ...           ...
# 471955       585       190496            0.104910     355      Bulgaria
# 471956       585       190507            0.000084     640        Turkey
# 471957       585       190508            0.000084     640        Turkey
# 471958       585       190510            0.000084     640        Turkey
# 471959       585       190511            0.000084     640        Turkey
#
# [471960 rows x 5 columns]

# %%
# add steps
pgm_data_new['step'] = pgm_data_new['month_id'] - EndOfHistory
pgm_data_new
# Out:
#         month_id  priogrid_id  pred_ln_ged_sb_dep  gwcode          name  step
# 0            550        62356            0.000005     560  South Africa     1
# 1            550        79599            0.000003     560  South Africa     1
# 2            550        79600            0.000004     560  South Africa     1
# 3            550        79601            0.000003     560  South Africa     1
# 4            550        80317            0.000006     560  South Africa     1
# ...          ...          ...                 ...     ...           ...   ...
# 471955       585       190496            0.104910     355      Bulgaria    36
# 471956       585       190507            0.000084     640        Turkey    36
# 471957       585       190508            0.000084     640        Turkey    36
# 471958       585       190510            0.000084     640        Turkey    36
# 471959       585       190511            0.000084     640        Turkey    36
#
# [471960 rows x 6 columns]

# %%
final_pgm_data_new = pd.merge(pgm_data_new, gdf_pgm, on="priogrid_id", how="left")
gdf_pgm_new = gpd.GeoDataFrame(final_pgm_data_new, geometry="geom")  
gdf_pgm_new
# Out:
#         month_id  priogrid_id  pred_ln_ged_sb_dep  gwcode          name  step  \
# 0            550        62356            0.000005     560  South Africa     1
# 1            550        79599            0.000003     560  South Africa     1
# 2            550        79600            0.000004     560  South Africa     1
# 3            550        79601            0.000003     560  South Africa     1
# 4            550        80317            0.000006     560  South Africa     1
# ...          ...          ...                 ...     ...           ...   ...
# 471955       585       190496            0.104910     355      Bulgaria    36
# 471956       585       190507            0.000084     640        Turkey    36
# 471957       585       190508            0.000084     640        Turkey    36
# 471958       585       190510            0.000084     640        Turkey    36
# 471959       585       190511            0.000084     640        Turkey    36
#
#         in_africa  in_me                                               geom
# 0            True  False  POLYGON ((37.50000 -47.00000, 37.50000 -46.500...
# 1            True  False  POLYGON ((19.00000 -35.00000, 19.00000 -34.500...
# 2            True  False  POLYGON ((19.50000 -35.00000, 19.50000 -34.500...
# 3            True  False  POLYGON ((20.00000 -35.00000, 20.00000 -34.500...
# 4            True  False  POLYGON ((18.00000 -34.50000, 18.00000 -34.000...
# ...           ...    ...                                                ...
# 471955      False   True  POLYGON ((27.50000 42.00000, 27.50000 42.50000...
# 471956      False   True  POLYGON ((33.00000 42.00000, 33.00000 42.50000...
# 471957      False   True  POLYGON ((33.50000 42.00000, 33.50000 42.50000...
# 471958      False   True  POLYGON ((34.50000 42.00000, 34.50000 42.50000...
# 471959      False   True  POLYGON ((35.00000 42.00000, 35.00000 42.50000...
#
# [471960 rows x 9 columns]

# %%
# PGM - NEW

for step in steps:

    # Generate month to plot based on first month of selected dataset and the step chosen above

    t = (new_data_pgm['month_id'].min())-1
    month_to_plot = t + step 
    month_to_plot

    pgm_data_to_plot = gdf_pgm_new[gdf_pgm_new['month_id'] == month_to_plot]  
    region = 'ame' #options are 'ame', 'me' or 'globe'

    cmap = ['rainbow']
    #cmap = ['rainbow', 'binary']

    for cmaps in cmap:
        test_map = Mapper2(
        width=10,   # dimension width
        height=10,  # dimension height
        frame_on=True,
        bbox=bbox_from_cid(f'{region}'), 
        ).add_layer(
        gdf=pgm_data_to_plot,  
        cmap=cmaps,
        transparency=1,
        background=None, 
        map_dictionary=custom_1p, # changed based on column
        edgecolor="black",  # border color choice
        linewidth=0.05,  # line size choice
        column="pred_ln_ged_sb_dep", 
        )
        # Jim procedure for country border creation using the geometries inherent to views3
        ax = test_map.ax
        gdf_cm.plot(ax=ax, edgecolor='black', linewidth=0.01, facecolor='None')

    
    # Save the map with appropriate filename
    test_map.save(f'{desktop}/new_run_{EndOfHistory}_pgm_s{step}_ln1_{region}_{cmaps}', dpi=350)

    # Print map status
    print(f'{cmaps} map for step {step} saved to {desktop}/new_run_{EndOfHistory}_m_s{step}_ln1_{region}_{cmaps}!')
# Out:
# rainbow map for step 1 saved to /Users/alm/Desktop//new_run_549_m_s1_ln1_ame_rainbow!
# rainbow map for step 3 saved to /Users/alm/Desktop//new_run_549_m_s3_ln1_ame_rainbow!
# rainbow map for step 6 saved to /Users/alm/Desktop//new_run_549_m_s6_ln1_ame_rainbow!
# rainbow map for step 12 saved to /Users/alm/Desktop//new_run_549_m_s12_ln1_ame_rainbow!
# rainbow map for step 24 saved to /Users/alm/Desktop//new_run_549_m_s24_ln1_ame_rainbow!
# rainbow map for step 36 saved to /Users/alm/Desktop//new_run_549_m_s36_ln1_ame_rainbow!

# %% [markdown]
# #  Plot old pipeline data

# %% [markdown]
# ### CM

# %%
old_data_cm
# Out:
# feature              step_combined
# month_id country_id
# 550      1                0.001749
#          2                0.003540
#          3                0.043151
#          4                0.742192
#          5                0.009478
# ...                            ...
# 585      242              0.343062
#          243              0.629551
#          244              0.317161
#          245              5.258471
#          246              3.352334
#
# [6876 rows x 1 columns]

# %%
old_data_cm = old_data_cm.reset_index()
old_data_cm['step'] = old_data_cm['month_id'] - EndOfHistory
old_data_cm = old_data_cm.set_index(['step', 'country_id'], drop = True)
old_data_cm
# Out:
# feature          month_id  step_combined
# step country_id
# 1    1                550       0.001749
#      2                550       0.003540
#      3                550       0.043151
#      4                550       0.742192
#      5                550       0.009478
# ...                   ...            ...
# 36   242              585       0.343062
#      243              585       0.629551
#      244              585       0.317161
#      245              585       5.258471
#      246              585       3.352334
#
# [6876 rows x 2 columns]

# %%
cm_data_old = pd.merge(old_data_cm, gdf_cm, on="country_id", how="left")
gdf_cm_old = gpd.GeoDataFrame(cm_data_old, geometry="geom")

gdf_cm_old
# Out:
#       country_id  month_id  step_combined                 name  in_africa  \
# 0              1       550       0.001749               Guyana          0
# 1              2       550       0.003540             Suriname          0
# 2              3       550       0.043151  Trinidad and Tobago          0
# 3              4       550       0.742192            Venezuela          0
# 4              5       550       0.009478                Samoa          0
# ...          ...       ...            ...                  ...        ...
# 6871         242       585       0.343062             Tanzania          1
# 6872         243       585       0.629551              Morocco          1
# 6873         244       585       0.317161           Mauritania          1
# 6874         245       585       5.258471                Sudan          1
# 6875         246       585       3.352334          South Sudan          1
#
#       in_me                                               geom
# 0         0  MULTIPOLYGON (((-58.17262 6.81222, -58.15494 6...
# 1         0  MULTIPOLYGON (((-55.12796 5.82217, -55.10445 5...
# 2         0  MULTIPOLYGON (((-61.07945 10.82416, -61.07556 ...
# 3         0  MULTIPOLYGON (((-66.31029 10.62602, -66.28309 ...
# 4         0  MULTIPOLYGON (((-172.59650 -13.50911, -172.551...
# ...     ...                                                ...
# 6871      0  MULTIPOLYGON (((34.13636 -9.57117, 34.07444 -9...
# 6872      0  MULTIPOLYGON (((-4.42042 35.15125, -4.35792 35...
# 6873      0  MULTIPOLYGON (((-10.71639 15.43890, -10.71945 ...
# 6874      0  MULTIPOLYGON (((34.09223 9.47747, 33.90162 9.4...
# 6875      0  MULTIPOLYGON (((34.09223 9.47747, 34.09416 9.4...
#
# [6876 rows x 7 columns]

# %%
# CM - OLD

for step in steps:

    # Generate month to plot based on first month of selected dataset and the step chosen above

    t = (old_data_cm['month_id'].min())-1
    month_to_plot = t + step 
    month_to_plot

    cm_data_to_plot = gdf_cm_old[gdf_cm_old['month_id'] == month_to_plot]  

    region = 'globe' #options are 'ame', 'me' or 'globe'

    cmap = ['rainbow']

    for cmaps in cmap:
        test_map = Mapper2(
        width=10,   # dimension width
        height=10,  # dimension height
        frame_on=True,
        bbox=bbox_from_cid(f'{region}'), 
        ).add_layer(
        gdf=cm_data_to_plot,  
        cmap=cmaps,
        transparency=1,
        background=None, 
        map_dictionary=dictionary_stand_1p_10k, # changed based on column
        edgecolor="black",  # border color choice
        linewidth=0.15,  # line size choice
        column="step_combined", 
        )

    # Save the map with appropriate filename
    test_map.save(f'{desktop}/old_run_{EndOfHistory}_cm_s{step}_ln1_{region}_{cmaps}', dpi=350)

    # Print map status
    print(f'{cmaps} map for step {step} saved to {desktop}/old_run_{EndOfHistory}_cm_s{step}_ln1_{region}_{cmaps}!')
# Out:
# rainbow map for step 1 saved to /Users/alm/Desktop//old_run_549_cm_s1_ln1_globe_rainbow!
# rainbow map for step 3 saved to /Users/alm/Desktop//old_run_549_cm_s3_ln1_globe_rainbow!
# rainbow map for step 6 saved to /Users/alm/Desktop//old_run_549_cm_s6_ln1_globe_rainbow!
# rainbow map for step 12 saved to /Users/alm/Desktop//old_run_549_cm_s12_ln1_globe_rainbow!
# rainbow map for step 24 saved to /Users/alm/Desktop//old_run_549_cm_s24_ln1_globe_rainbow!
# rainbow map for step 36 saved to /Users/alm/Desktop//old_run_549_cm_s36_ln1_globe_rainbow!

# %% [markdown]
# ### PGM

# %%
old_data_pgm
# Out:
# feature               step_combined
# month_id priogrid_id
# 550      62356             0.000184
#          79599             0.000081
#          79600             0.000078
#          79601             0.000074
#          80317             0.000103
# ...                             ...
# 585      190496            0.009952
#          190507            0.001289
#          190508            0.001099
#          190510            0.001199
#          190511            0.001106
#
# [471960 rows x 1 columns]

# %%
old_data_pgm = old_data_pgm.reset_index()
old_data_pgm['step'] = old_data_pgm['month_id'] - EndOfHistory
old_data_pgm = old_data_pgm.set_index(['step', 'priogrid_id'], drop = True)
old_data_pgm
# Out:
# feature           month_id  step_combined
# step priogrid_id
# 1    62356             550       0.000184
#      79599             550       0.000081
#      79600             550       0.000078
#      79601             550       0.000074
#      80317             550       0.000103
# ...                    ...            ...
# 36   190496            585       0.009952
#      190507            585       0.001289
#      190508            585       0.001099
#      190510            585       0.001199
#      190511            585       0.001106
#
# [471960 rows x 2 columns]

# %%
pgm_data_old = pd.merge(old_data_pgm, gdf_pgm, on="priogrid_id", how="left")
gdf_pgm_old = gpd.GeoDataFrame(pgm_data_old, geometry="geom")  

gdf_pgm_old
# Out:
#         priogrid_id  month_id  step_combined  in_africa  in_me  \
# 0             62356       550       0.000184       True  False
# 1             79599       550       0.000081       True  False
# 2             79600       550       0.000078       True  False
# 3             79601       550       0.000074       True  False
# 4             80317       550       0.000103       True  False
# ...             ...       ...            ...        ...    ...
# 471955       190496       585       0.009952      False   True
# 471956       190507       585       0.001289      False   True
# 471957       190508       585       0.001099      False   True
# 471958       190510       585       0.001199      False   True
# 471959       190511       585       0.001106      False   True
#
#                                                      geom
# 0       POLYGON ((37.50000 -47.00000, 37.50000 -46.500...
# 1       POLYGON ((19.00000 -35.00000, 19.00000 -34.500...
# 2       POLYGON ((19.50000 -35.00000, 19.50000 -34.500...
# 3       POLYGON ((20.00000 -35.00000, 20.00000 -34.500...
# 4       POLYGON ((18.00000 -34.50000, 18.00000 -34.000...
# ...                                                   ...
# 471955  POLYGON ((27.50000 42.00000, 27.50000 42.50000...
# 471956  POLYGON ((33.00000 42.00000, 33.00000 42.50000...
# 471957  POLYGON ((33.50000 42.00000, 33.50000 42.50000...
# 471958  POLYGON ((34.50000 42.00000, 34.50000 42.50000...
# 471959  POLYGON ((35.00000 42.00000, 35.00000 42.50000...
#
# [471960 rows x 6 columns]

# %%
# PGM

for step in steps:

    # Generate month to plot based on first month of selected dataset and the step chosen above

    t = (old_data_pgm['month_id'].min())-1
    month_to_plot = t + step 
    month_to_plot

    pgm_data_to_plot = gdf_pgm_old[gdf_pgm_old['month_id'] == month_to_plot]  

    region = 'ame' #options are 'ame', 'me' or 'globe'

    cmap = ['rainbow']
    #cmap = ['rainbow', 'binary']

    for cmaps in cmap:
        test_map = Mapper2(
        width=10,   # dimension width
        height=10,  # dimension height
        frame_on=True,
        bbox=bbox_from_cid(f'{region}'), 
        ).add_layer(
        gdf=pgm_data_to_plot,  
        cmap=cmaps,
        transparency=1,
        background=None, 
        map_dictionary=custom_1p, # changed based on column
        edgecolor="black",  # border color choice
        linewidth=0.05,  # line size choice
        column="step_combined", 
        )
        # Jim procedure for country border creation using the geometries inherent to views3
        ax = test_map.ax
        gdf_cm.plot(ax=ax, edgecolor='black', linewidth=0.01, facecolor='None')

    
    # Save the map with appropriate filename
    test_map.save(f'{desktop}/old_run_{EndOfHistory}_pgm_s{step}_ln1_{region}_{cmaps}', dpi=350)

    # Print map status
    print(f'{cmaps} map for step {step} saved to {desktop}/old_run_{EndOfHistory}_pgm_s{step}_ln1_{region}_{cmaps}!')
# Out:
# rainbow map for step 1 saved to /Users/alm/Desktop//old_run_549_pgm_s1_ln1_ame_rainbow!
# rainbow map for step 3 saved to /Users/alm/Desktop//old_run_549_pgm_s3_ln1_ame_rainbow!
# rainbow map for step 6 saved to /Users/alm/Desktop//old_run_549_pgm_s6_ln1_ame_rainbow!
# rainbow map for step 12 saved to /Users/alm/Desktop//old_run_549_pgm_s12_ln1_ame_rainbow!
# rainbow map for step 24 saved to /Users/alm/Desktop//old_run_549_pgm_s24_ln1_ame_rainbow!
# rainbow map for step 36 saved to /Users/alm/Desktop//old_run_549_pgm_s36_ln1_ame_rainbow!

# %% [markdown]
# ## Check reconciliation between CM and PGM data in the new pipeline

# %% [markdown]
# ### Sum PGM predictions by country-month

# %%
gdf_pgm_new
# Out:
#         month_id  priogrid_id  pred_ln_ged_sb_dep  gwcode          name  step  \
# 0            550        62356            0.000005     560  South Africa     1
# 1            550        79599            0.000003     560  South Africa     1
# 2            550        79600            0.000004     560  South Africa     1
# 3            550        79601            0.000003     560  South Africa     1
# 4            550        80317            0.000006     560  South Africa     1
# ...          ...          ...                 ...     ...           ...   ...
# 471955       585       190496            0.104910     355      Bulgaria    36
# 471956       585       190507            0.000084     640        Turkey    36
# 471957       585       190508            0.000084     640        Turkey    36
# 471958       585       190510            0.000084     640        Turkey    36
# 471959       585       190511            0.000084     640        Turkey    36
#
#         in_africa  in_me                                               geom
# 0            True  False  POLYGON ((37.50000 -47.00000, 37.50000 -46.500...
# 1            True  False  POLYGON ((19.00000 -35.00000, 19.00000 -34.500...
# 2            True  False  POLYGON ((19.50000 -35.00000, 19.50000 -34.500...
# 3            True  False  POLYGON ((20.00000 -35.00000, 20.00000 -34.500...
# 4            True  False  POLYGON ((18.00000 -34.50000, 18.00000 -34.000...
# ...           ...    ...                                                ...
# 471955      False   True  POLYGON ((27.50000 42.00000, 27.50000 42.50000...
# 471956      False   True  POLYGON ((33.00000 42.00000, 33.00000 42.50000...
# 471957      False   True  POLYGON ((33.50000 42.00000, 33.50000 42.50000...
# 471958      False   True  POLYGON ((34.50000 42.00000, 34.50000 42.50000...
# 471959      False   True  POLYGON ((35.00000 42.00000, 35.00000 42.50000...
#
# [471960 rows x 9 columns]

# %%
gdf_pgm_new['pred_linear_ged_sb_dep'] = np.expm1(gdf_pgm_new['pred_ln_ged_sb_dep'])
gdf_pgm_new
# Out:
#         month_id  priogrid_id  pred_ln_ged_sb_dep  gwcode          name  step  \
# 0            550        62356            0.000005     560  South Africa     1
# 1            550        79599            0.000003     560  South Africa     1
# 2            550        79600            0.000004     560  South Africa     1
# 3            550        79601            0.000003     560  South Africa     1
# 4            550        80317            0.000006     560  South Africa     1
# ...          ...          ...                 ...     ...           ...   ...
# 471955       585       190496            0.104910     355      Bulgaria    36
# 471956       585       190507            0.000084     640        Turkey    36
# 471957       585       190508            0.000084     640        Turkey    36
# 471958       585       190510            0.000084     640        Turkey    36
# 471959       585       190511            0.000084     640        Turkey    36
#
#         in_africa  in_me                                               geom  \
# 0            True  False  POLYGON ((37.50000 -47.00000, 37.50000 -46.500...
# 1            True  False  POLYGON ((19.00000 -35.00000, 19.00000 -34.500...
# 2            True  False  POLYGON ((19.50000 -35.00000, 19.50000 -34.500...
# 3            True  False  POLYGON ((20.00000 -35.00000, 20.00000 -34.500...
# 4            True  False  POLYGON ((18.00000 -34.50000, 18.00000 -34.000...
# ...           ...    ...                                                ...
# 471955      False   True  POLYGON ((27.50000 42.00000, 27.50000 42.50000...
# 471956      False   True  POLYGON ((33.00000 42.00000, 33.00000 42.50000...
# 471957      False   True  POLYGON ((33.50000 42.00000, 33.50000 42.50000...
# 471958      False   True  POLYGON ((34.50000 42.00000, 34.50000 42.50000...
# 471959      False   True  POLYGON ((35.00000 42.00000, 35.00000 42.50000...
#
#         pred_linear_ged_sb_dep
# 0                     0.000005
# 1                     0.000003
# 2                     0.000004
# 3                     0.000003
# 4                     0.000006
# ...                        ...
# 471955                0.110610
# 471956                0.000084
# 471957                0.000084
# 471958                0.000084
# 471959                0.000084
#
# [471960 rows x 10 columns]

# %%
df_sum_pgm = (
    gdf_pgm_new.groupby(["name", "month_id", "gwcode"])["pred_linear_ged_sb_dep"]
      .sum()
      .reset_index()
)
df_sum_pgm = df_sum_pgm.rename(columns={'pred_linear_ged_sb_dep':'sum_pgm_pred_linear_ged_sb_dep'})
df_sum_pgm
# Out:
#              name  month_id  gwcode  sum_pgm_pred_linear_ged_sb_dep
# 0     Afghanistan       550     700                       11.454067
# 1     Afghanistan       551     700                       12.550658
# 2     Afghanistan       552     700                       13.316750
# 3     Afghanistan       553     700                       12.034202
# 4     Afghanistan       554     700                       12.634485
# ...           ...       ...     ...                             ...
# 2731     Zimbabwe       581     552                        0.054956
# 2732     Zimbabwe       582     552                        0.072248
# 2733     Zimbabwe       583     552                        0.076165
# 2734     Zimbabwe       584     552                        0.071036
# 2735     Zimbabwe       585     552                        0.078832
#
# [2736 rows x 4 columns]

# %% [markdown]
# ### Fetch CM identifiers

# %%
qs_c = (Queryset("c_data", "country_month")

               # target variable
               .with_column(Column("gwcode", from_loa="country", from_column="gwcode")
                            )
               .with_column(Column("name", from_loa="country", from_column="name")
                            )
        )
c_data=qs_c.publish().fetch()
# Out:
# Queryset c_data read successfully

# %%
c_data = c_data.reset_index()
c_data
# Out:
#          index  month_id  country_id  gwcode                 name
# 0            0         1           1     110               Guyana
# 1            1         1           2     115             Suriname
# 2            2         1           3      52  Trinidad and Tobago
# 3            3         1           4     101            Venezuela
# 4            4         1           5     990                Samoa
# ...        ...       ...         ...     ...                  ...
# 158225  158225       852         242     510             Tanzania
# 158226  158226       852         243     600              Morocco
# 158227  158227       852         244     435           Mauritania
# 158228  158228       852         245     625                Sudan
# 158229  158229       852         246     626          South Sudan
#
# [158230 rows x 5 columns]

# %% [markdown]
# ### Merge CM predictions with identifiers

# %%
new_cm_df = new_data_cm.reset_index()
new_cm_df
# Out:
#       step  country_id  month_id  pred_ln_ged_sb_dep
# 0        1           1       550            0.003773
# 1        1           2       550            0.003762
# 2        1           3       550            0.011403
# 3        1           4       550            0.713244
# 4        1           5       550            0.003762
# ...    ...         ...       ...                 ...
# 6871    36         242       585            0.105974
# 6872    36         243       585            0.378329
# 6873    36         244       585            0.107760
# 6874    36         245       585            3.757777
# 6875    36         246       585            2.260278
#
# [6876 rows x 4 columns]

# %%
new_cm_df['pred_linear_ged_sb_dep'] = np.expm1(new_cm_df['pred_ln_ged_sb_dep'])
new_cm_df
# Out:
#       step  country_id  month_id  pred_ln_ged_sb_dep  pred_linear_ged_sb_dep
# 0        1           1       550            0.003773                0.003780
# 1        1           2       550            0.003762                0.003769
# 2        1           3       550            0.011403                0.011468
# 3        1           4       550            0.713244                1.040601
# 4        1           5       550            0.003762                0.003769
# ...    ...         ...       ...                 ...                     ...
# 6871    36         242       585            0.105974                0.111793
# 6872    36         243       585            0.378329                0.459844
# 6873    36         244       585            0.107760                0.113780
# 6874    36         245       585            3.757777               41.853047
# 6875    36         246       585            2.260278                8.585755
#
# [6876 rows x 5 columns]

# %%
new_cm_df = new_cm_df.rename(columns={'pred_linear_ged_sb_dep':'sum_cm_pred_linear_ged_sb_dep'})
new_cm_df
# Out:
#       step  country_id  month_id  pred_ln_ged_sb_dep  \
# 0        1           1       550            0.003773
# 1        1           2       550            0.003762
# 2        1           3       550            0.011403
# 3        1           4       550            0.713244
# 4        1           5       550            0.003762
# ...    ...         ...       ...                 ...
# 6871    36         242       585            0.105974
# 6872    36         243       585            0.378329
# 6873    36         244       585            0.107760
# 6874    36         245       585            3.757777
# 6875    36         246       585            2.260278
#
#       sum_cm_pred_linear_ged_sb_dep
# 0                          0.003780
# 1                          0.003769
# 2                          0.011468
# 3                          1.040601
# 4                          0.003769
# ...                             ...
# 6871                       0.111793
# 6872                       0.459844
# 6873                       0.113780
# 6874                      41.853047
# 6875                       8.585755
#
# [6876 rows x 5 columns]

# %%
df_sum_cm = pd.merge(new_cm_df, c_data, on=["country_id", "month_id"], how="left")
df_sum_cm.sort_values(by=['name', 'month_id'], inplace=True)
df_sum_cm
# Out:
#       step  country_id  month_id  pred_ln_ged_sb_dep  \
# 119      1         133       550            2.522047
# 310      2         133       551            2.606435
# 501      3         133       552            2.661430
# 692      4         133       553            2.567577
# 883      5         133       554            2.612602
# ...    ...         ...       ...                 ...
# 6064    32         158       581            0.053499
# 6255    33         158       582            0.069758
# 6446    34         158       583            0.073404
# 6637    35         158       584            0.068626
# 6828    36         158       585            0.075879
#
#       sum_cm_pred_linear_ged_sb_dep   index  gwcode         name
# 119                       11.454070  100476     700  Afghanistan
# 310                       12.550661  100667     700  Afghanistan
# 501                       13.316754  100858     700  Afghanistan
# 692                       12.034202  101049     700  Afghanistan
# 883                       12.634488  101240     700  Afghanistan
# ...                             ...     ...     ...          ...
# 6064                       0.054956  106421     552     Zimbabwe
# 6255                       0.072249  106612     552     Zimbabwe
# 6446                       0.076165  106803     552     Zimbabwe
# 6637                       0.071036  106994     552     Zimbabwe
# 6828                       0.078832  107185     552     Zimbabwe
#
# [6876 rows x 8 columns]

# %% [markdown]
# ## Merge CM and PGM dfs with country-months sums

# %%
# Check pgm df one last time
df_sum_pgm
# Out:
#              name  month_id  gwcode  sum_pgm_pred_linear_ged_sb_dep
# 0     Afghanistan       550     700                       11.454067
# 1     Afghanistan       551     700                       12.550658
# 2     Afghanistan       552     700                       13.316750
# 3     Afghanistan       553     700                       12.034202
# 4     Afghanistan       554     700                       12.634485
# ...           ...       ...     ...                             ...
# 2731     Zimbabwe       581     552                        0.054956
# 2732     Zimbabwe       582     552                        0.072248
# 2733     Zimbabwe       583     552                        0.076165
# 2734     Zimbabwe       584     552                        0.071036
# 2735     Zimbabwe       585     552                        0.078832
#
# [2736 rows x 4 columns]

# %%
df_sum_final = pd.merge( df_sum_pgm, df_sum_cm, on=["month_id", "gwcode", "name"], how="left")
df_sum_final
# Out:
#              name  month_id  gwcode  sum_pgm_pred_linear_ged_sb_dep  step  \
# 0     Afghanistan       550     700                       11.454067     1
# 1     Afghanistan       551     700                       12.550658     2
# 2     Afghanistan       552     700                       13.316750     3
# 3     Afghanistan       553     700                       12.034202     4
# 4     Afghanistan       554     700                       12.634485     5
# ...           ...       ...     ...                             ...   ...
# 2731     Zimbabwe       581     552                        0.054956    32
# 2732     Zimbabwe       582     552                        0.072248    33
# 2733     Zimbabwe       583     552                        0.076165    34
# 2734     Zimbabwe       584     552                        0.071036    35
# 2735     Zimbabwe       585     552                        0.078832    36
#
#       country_id  pred_ln_ged_sb_dep  sum_cm_pred_linear_ged_sb_dep   index
# 0            133            2.522047                      11.454070  100476
# 1            133            2.606435                      12.550661  100667
# 2            133            2.661430                      13.316754  100858
# 3            133            2.567577                      12.034202  101049
# 4            133            2.612602                      12.634488  101240
# ...          ...                 ...                            ...     ...
# 2731         158            0.053499                       0.054956  106421
# 2732         158            0.069758                       0.072249  106612
# 2733         158            0.073404                       0.076165  106803
# 2734         158            0.068626                       0.071036  106994
# 2735         158            0.075879                       0.078832  107185
#
# [2736 rows x 9 columns]

# %%
print('All done!')
# Out:
# All done!
